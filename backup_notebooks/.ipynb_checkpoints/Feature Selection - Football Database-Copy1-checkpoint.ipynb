# %% [markdown]
# # Feature Selection

# %% [markdown]
# Choosing the most effective variables

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import os
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn import ensemble, tree, linear_model
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer
from scipy.stats import pearsonr

plt.style.use('seaborn')
import re
from scipy import stats
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from scipy.stats import f_oneway
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy.stats import ks_2samp
from scipy.stats import norm
import missingno as msno
import datetime
import pickle

# %%
# load dataframes
with open("../pickles/df_after_feature_engineering.pkl", "rb") as f:
    df = pickle.load(f)

# %%
df.head()
# Out:
#       gameID  leagueID  season                date  homeTeamID  awayTeamID  \
# 5437    6185         5    2014 2014-08-08 19:30:00         177         161
# 5438    6186         5    2014 2014-08-09 20:00:00         162         164
# 5439    6187         5    2014 2014-08-09 20:00:00         209         165
# 5440    6188         5    2014 2014-08-09 20:00:00         169         175
# 5441    6189         5    2014 2014-08-09 20:00:00         160         180
#
#       home_Goals  away_Goals  home_GoalsHalfTime  away_GoalsHalfTime  ...  \
# 5437           2           2                   2                   1  ...
# 5438           3           3                   1                   2  ...
# 5439           0           3                   0                   3  ...
# 5440           0           2                   0                   1  ...
# 5441           0           0                   0                   0  ...
#
#       recent_form_diff  interaction_goal_rate_vs_blocks  \
# 5437               0.0                         0.000000
# 5438               0.0                         0.000000
# 5439               0.0                         1.713977
# 5440               0.0                         1.259045
# 5441               0.0                         0.227264
#
#       interaction_goal_rate_vs_conceded  \
# 5437                           0.000000
# 5438                           0.000000
# 5439                        9523.809524
# 5440                           0.074073
# 5441                           0.040404
#
#       interaction_xG_efficiency_vs_shots_conceded  \
# 5437                                     0.000000
# 5438                                     0.000000
# 5439                                174392.090970
# 5440                                     1.113665
# 5441                                     0.536304
#
#       rolling_xG_vs_shot_conceded  rolling_shot_rate_vs_blocks  \
# 5437                          0.0                          0.0
# 5438                          0.0                          0.0
# 5439                          0.0                          0.0
# 5440                          0.0                          0.0
# 5441                          0.0                          0.0
#
#       discipline_matchup_score  interaction_away_goal_rate_vs_home_def  \
# 5437                  0.000000                                0.000000
# 5438                  0.000000                                0.392846
# 5439                  0.006144                                1.499865
# 5440                  0.004831                                0.473663
# 5441                  0.003565                                0.760592
#
#       interaction_away_form_vs_home_cards  form_vs_discipline_gap
# 5437                             0.000000                0.000000
# 5438                             0.047790               -0.028571
# 5439                             0.070921               -0.035714
# 5440                             0.066536               -0.031189
# 5441                             0.068226               -0.002229
#
# [5 rows x 107 columns]

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12680 entries, 5437 to 12679
# Data columns (total 107 columns):
#  #    Column                                       Dtype
# ---   ------                                       -----
#  0    gameID                                       int64
#  1    leagueID                                     int64
#  2    season                                       int64
#  3    date                                         datetime64[ns]
#  4    homeTeamID                                   int64
#  5    awayTeamID                                   int64
#  6    home_Goals                                   int64
#  7    away_Goals                                   int64
#  8    home_GoalsHalfTime                           int64
#  9    away_GoalsHalfTime                           int64
#  10   home_xGoals                                  float64
#  11   home_shots                                   float64
#  12   home_shotsOnTarget                           int64
#  13   home_deep                                    float64
#  14   home_ppda                                    float64
#  15   home_fouls                                   float64
#  16   home_corners                                 float64
#  17   home_yellowCards                             int64
#  18   home_redCards                                int64
#  19   home_total_assists                           int64
#  20   home_total_xAssists                          float64
#  21   home_total_key_passes                        float64
#  22   home_total_xGoalsChain                       float64
#  23   home_total_xGoalsBuildup                     float64
#  24   home_total_yellow_cards                      int64
#  25   home_total_red_cards                         int64
#  26   home_total_blocked_shots                     float64
#  27   home_total_saved_shots                       float64
#  28   away_xGoals                                  float64
#  29   away_shots                                   float64
#  30   away_shotsOnTarget                           int64
#  31   away_deep                                    float64
#  32   away_ppda                                    float64
#  33   away_fouls                                   float64
#  34   away_corners                                 int64
#  35   away_yellowCards                             int64
#  36   away_redCards                                int64
#  37   away_total_assists                           int64
#  38   away_total_xAssists                          float64
#  39   away_total_key_passes                        float64
#  40   away_total_xGoalsChain                       float64
#  41   away_total_xGoalsBuildup                     float64
#  42   away_total_yellow_cards                      int64
#  43   away_total_red_cards                         int64
#  44   away_total_blocked_shots                     float64
#  45   away_total_saved_shots                       float64
#  46   gameresult                                   int64
#  47   home_redCards_binary                         bool
#  48   away_redCards_binary                         bool
#  49   home_yellowCards_cat                         category
#  50   away_yellowCards_cat                         category
#  51   home_shotsOnTarget_cat                       category
#  52   away_shotsOnTarget_cat                       category
#  53   home_total_assists_cat                       category
#  54   away_total_assists_cat                       category
#  55   home_corners_cat                             category
#  56   away_corners_cat                             category
#  57   home_Goals_cat                               category
#  58   away_Goals_cat                               category
#  59   home_total_blocked_shots_cat                 category
#  60   away_total_blocked_shots_cat                 category
#  61   home_total_saved_shots_cat                   category
#  62   away_total_saved_shots_cat                   category
#  63   year                                         int64
#  64   month                                        int64
#  65   day                                          int64
#  66   time_category                                object
#  67   is_weekend                                   bool
#  68   home_cumulative_goals_for                    float64
#  69   away_cumulative_goals_for                    float64
#  70   home_cumulative_goals_against                float64
#  71   away_cumulative_goals_against                float64
#  72   home_cumulative_goal_diff                    float64
#  73   away_cumulative_goal_diff                    float64
#  74   home_avg_goals_for                           float64
#  75   away_avg_goals_for                           float64
#  76   home_avg_goals_against                       float64
#  77   away_avg_goals_against                       float64
#  78   home_goal_per_shot                           float64
#  79   away_goal_per_shot                           float64
#  80   home_goal_per_xg                             float64
#  81   away_goal_per_xg                             float64
#  82   home_rolling_goal_per_shot                   float64
#  83   away_rolling_goal_per_shot                   float64
#  84   home_rolling_goal_per_xg                     float64
#  85   away_rolling_goal_per_xg                     float64
#  86   home_blocked_shot_ratio                      float64
#  87   away_blocked_shot_ratio                      float64
#  88   home_shot_conceded_ratio                     float64
#  89   away_shot_conceded_ratio                     float64
#  90   home_discipline_score                        float64
#  91   away_discipline_score                        float64
#  92   home_discipline_score_avg                    float64
#  93   away_discipline_score_avg                    float64
#  94   home_adv_goal_diff                           float64
#  95   home_adv_avg_goals                           float64
#  96   points_diff                                  float64
#  97   recent_form_diff                             float64
#  98   interaction_goal_rate_vs_blocks              float64
#  99   interaction_goal_rate_vs_conceded            float64
#  100  interaction_xG_efficiency_vs_shots_conceded  float64
#  101  rolling_xG_vs_shot_conceded                  float64
#  102  rolling_shot_rate_vs_blocks                  float64
#  103  discipline_matchup_score                     float64
#  104  interaction_away_goal_rate_vs_home_def       float64
#  105  interaction_away_form_vs_home_cards          float64
#  106  form_vs_discipline_gap                       float64
# dtypes: bool(3), category(14), datetime64[ns](1), float64(62), int64(26), object(1)
# memory usage: 9.0+ MB

# %% [markdown]
# lets droop columns that are high related with the target value and columns that are unnecesary (like date, duplicates...)

# %%
cols_to_drop = ['home_Goals','away_Goals','home_GoalsHalfTime','away_GoalsHalfTime','date',
                'home_yellowCards', 'home_redCards','away_yellowCards', 'away_redCards','home_total_yellow_cards',
               'home_total_yellow_cards','away_total_red_cards','home_total_red_cards','away_shotsOnTarget','home_shotsOnTarget',
               'home_total_assists','away_total_assists','home_corners','away_corners','home_Goals_cat','away_Goals_cat',
               'home_total_blocked_shots','away_total_blocked_shots','home_total_saved_shots','away_total_saved_shots',
               'gameID','homeTeamID','awayTeamID','home_total_assists_cat','away_total_assists_cat','home_total_xGoalsBuildup',
               'away_total_xGoalsBuildup']

# %%
df_for_selection = df.drop(columns=cols_to_drop)

# %%
# saving df for selection
with open("../pickles/df_for_selection.pkl", "wb") as f:
    pickle.dump(df_for_selection, f)  # Save the DataFrame with standard pickle

# %%
df = df_for_selection

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12680 entries, 5437 to 12679
# Data columns (total 76 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   leagueID                                     12680 non-null  int64
#  1   season                                       12680 non-null  int64
#  2   home_xGoals                                  12680 non-null  float64
#  3   home_shots                                   12680 non-null  float64
#  4   home_deep                                    12680 non-null  float64
#  5   home_ppda                                    12680 non-null  float64
#  6   home_fouls                                   12680 non-null  float64
#  7   home_total_xAssists                          12680 non-null  float64
#  8   home_total_key_passes                        12680 non-null  float64
#  9   home_total_xGoalsChain                       12680 non-null  float64
#  10  away_xGoals                                  12680 non-null  float64
#  11  away_shots                                   12680 non-null  float64
#  12  away_deep                                    12680 non-null  float64
#  13  away_ppda                                    12680 non-null  float64
#  14  away_fouls                                   12680 non-null  float64
#  15  away_total_xAssists                          12680 non-null  float64
#  16  away_total_key_passes                        12680 non-null  float64
#  17  away_total_xGoalsChain                       12680 non-null  float64
#  18  away_total_yellow_cards                      12680 non-null  int64
#  19  gameresult                                   12680 non-null  int64
#  20  home_redCards_binary                         12680 non-null  bool
#  21  away_redCards_binary                         12680 non-null  bool
#  22  home_yellowCards_cat                         12680 non-null  category
#  23  away_yellowCards_cat                         12680 non-null  category
#  24  home_shotsOnTarget_cat                       12680 non-null  category
#  25  away_shotsOnTarget_cat                       12680 non-null  category
#  26  home_corners_cat                             12680 non-null  category
#  27  away_corners_cat                             12680 non-null  category
#  28  home_total_blocked_shots_cat                 12680 non-null  category
#  29  away_total_blocked_shots_cat                 12680 non-null  category
#  30  home_total_saved_shots_cat                   12680 non-null  category
#  31  away_total_saved_shots_cat                   12680 non-null  category
#  32  year                                         12680 non-null  int64
#  33  month                                        12680 non-null  int64
#  34  day                                          12680 non-null  int64
#  35  time_category                                12680 non-null  object
#  36  is_weekend                                   12680 non-null  bool
#  37  home_cumulative_goals_for                    12680 non-null  float64
#  38  away_cumulative_goals_for                    12680 non-null  float64
#  39  home_cumulative_goals_against                12680 non-null  float64
#  40  away_cumulative_goals_against                12680 non-null  float64
#  41  home_cumulative_goal_diff                    12680 non-null  float64
#  42  away_cumulative_goal_diff                    12680 non-null  float64
#  43  home_avg_goals_for                           12680 non-null  float64
#  44  away_avg_goals_for                           12680 non-null  float64
#  45  home_avg_goals_against                       12680 non-null  float64
#  46  away_avg_goals_against                       12680 non-null  float64
#  47  home_goal_per_shot                           12680 non-null  float64
#  48  away_goal_per_shot                           12680 non-null  float64
#  49  home_goal_per_xg                             12680 non-null  float64
#  50  away_goal_per_xg                             12680 non-null  float64
#  51  home_rolling_goal_per_shot                   12680 non-null  float64
#  52  away_rolling_goal_per_shot                   12680 non-null  float64
#  53  home_rolling_goal_per_xg                     12680 non-null  float64
#  54  away_rolling_goal_per_xg                     12680 non-null  float64
#  55  home_blocked_shot_ratio                      12680 non-null  float64
#  56  away_blocked_shot_ratio                      12680 non-null  float64
#  57  home_shot_conceded_ratio                     12680 non-null  float64
#  58  away_shot_conceded_ratio                     12680 non-null  float64
#  59  home_discipline_score                        12680 non-null  float64
#  60  away_discipline_score                        12680 non-null  float64
#  61  home_discipline_score_avg                    12680 non-null  float64
#  62  away_discipline_score_avg                    12680 non-null  float64
#  63  home_adv_goal_diff                           12680 non-null  float64
#  64  home_adv_avg_goals                           12680 non-null  float64
#  65  points_diff                                  12680 non-null  float64
#  66  recent_form_diff                             12680 non-null  float64
#  67  interaction_goal_rate_vs_blocks              12680 non-null  float64
#  68  interaction_goal_rate_vs_conceded            12680 non-null  float64
#  69  interaction_xG_efficiency_vs_shots_conceded  12680 non-null  float64
#  70  rolling_xG_vs_shot_conceded                  12680 non-null  float64
#  71  rolling_shot_rate_vs_blocks                  12680 non-null  float64
#  72  discipline_matchup_score                     12680 non-null  float64
#  73  interaction_away_goal_rate_vs_home_def       12680 non-null  float64
#  74  interaction_away_form_vs_home_cards          12680 non-null  float64
#  75  form_vs_discipline_gap                       12680 non-null  float64
# dtypes: bool(3), category(10), float64(55), int64(7), object(1)
# memory usage: 6.3+ MB

# %%
#Creating Variables dataframes
varSel = pd.DataFrame({'Variable': df.columns.drop('gameresult')})
varSel
# Out:
#                                   Variable
# 0                                 leagueID
# 1                                   season
# 2                              home_xGoals
# 3                               home_shots
# 4                                home_deep
# ..                                     ...
# 70             rolling_shot_rate_vs_blocks
# 71                discipline_matchup_score
# 72  interaction_away_goal_rate_vs_home_def
# 73     interaction_away_form_vs_home_cards
# 74                  form_vs_discipline_gap
#
# [75 rows x 1 columns]

# %% [markdown]
# ## Univariable Analysis

# %%
#from importlib import reload
from pyMechkar.analysis import Table1
#reload(tb1)

# %%
nm = df.columns.drop('gameresult')
nm = nm.append(pd.Index(['gameresult']))
nm
# Out:
# Index(['leagueID', 'season', 'home_xGoals', 'home_shots', 'home_deep',
#        'home_ppda', 'home_fouls', 'home_total_xAssists',
#        'home_total_key_passes', 'home_total_xGoalsChain', 'away_xGoals',
#        'away_shots', 'away_deep', 'away_ppda', 'away_fouls',
#        'away_total_xAssists', 'away_total_key_passes',
#        'away_total_xGoalsChain', 'away_total_yellow_cards',
#        'home_redCards_binary', 'away_redCards_binary', 'home_yellowCards_cat',
#        'away_yellowCards_cat', 'home_shotsOnTarget_cat',
#        'away_shotsOnTarget_cat', 'home_corners_cat', 'away_corners_cat',
#        'home_total_blocked_shots_cat', 'away_total_blocked_shots_cat',
#        'home_total_saved_shots_cat', 'away_total_saved_shots_cat', 'year',
#        'month', 'day', 'time_category', 'is_weekend',
#        'home_cumulative_goals_for', 'away_cumulative_goals_for',
#        'home_cumulative_goals_against', 'away_cumulative_goals_against',
#        'home_cumulative_goal_diff', 'away_cumulative_goal_diff',
#        'home_avg_goals_for', 'away_avg_goals_for', 'home_avg_goals_against',
#        'away_avg_goals_against', 'home_goal_per_shot', 'away_goal_per_shot',
#        'home_goal_per_xg', 'away_goal_per_xg', 'home_rolling_goal_per_shot',
#        'away_rolling_goal_per_shot', 'home_rolling_goal_per_xg',
#        'away_rolling_goal_per_xg', 'home_blocked_shot_ratio',
#        'away_blocked_shot_ratio', 'home_shot_conceded_ratio',
#        'away_shot_conceded_ratio', 'home_discipline_score',
#        'away_discipline_score', 'home_discipline_score_avg',
#        'away_discipline_score_avg', 'home_adv_goal_diff', 'home_adv_avg_goals',
#        'points_diff', 'recent_form_diff', 'interaction_goal_rate_vs_blocks',
#        'interaction_goal_rate_vs_conceded',
#        'interaction_xG_efficiency_vs_shots_conceded',
#        'rolling_xG_vs_shot_conceded', 'rolling_shot_rate_vs_blocks',
#        'discipline_matchup_score', 'interaction_away_goal_rate_vs_home_def',
#        'interaction_away_form_vs_home_cards', 'form_vs_discipline_gap',
#        'gameresult'],
#       dtype='object')

# %%
df2 = df[nm].copy()
df2.head()
# Out:
#       leagueID  season  home_xGoals  home_shots  home_deep  home_ppda  \
# 5437         5    2014     1.367870         9.0        2.0    31.6000
# 5438         5    2014     1.396890        14.0        2.0     5.7429
# 5439         5    2014     0.813737         9.0        3.0     7.0000
# 5440         5    2014     0.632940         6.0        3.0    16.0625
# 5441         5    2014     1.544680        14.0        5.0     3.6087
#
#       home_fouls  home_total_xAssists  home_total_key_passes  \
# 5437   15.000000             1.283730                    7.0
# 5438   12.597074             0.232187                    6.0
# 5439   12.000000             0.739955                    8.0
# 5440    9.000000             0.562167                    3.0
# 5441    9.000000             0.897067                    8.0
#
#       home_total_xGoalsChain  ...  interaction_goal_rate_vs_blocks  \
# 5437                2.784246  ...                         0.000000
# 5438                0.877201  ...                         0.000000
# 5439                3.146696  ...                         1.713977
# 5440                2.009705  ...                         1.259045
# 5441                0.864974  ...                         0.227264
#
#       interaction_goal_rate_vs_conceded  \
# 5437                           0.000000
# 5438                           0.000000
# 5439                        9523.809524
# 5440                           0.074073
# 5441                           0.040404
#
#       interaction_xG_efficiency_vs_shots_conceded  \
# 5437                                     0.000000
# 5438                                     0.000000
# 5439                                174392.090970
# 5440                                     1.113665
# 5441                                     0.536304
#
#       rolling_xG_vs_shot_conceded  rolling_shot_rate_vs_blocks  \
# 5437                          0.0                          0.0
# 5438                          0.0                          0.0
# 5439                          0.0                          0.0
# 5440                          0.0                          0.0
# 5441                          0.0                          0.0
#
#       discipline_matchup_score  interaction_away_goal_rate_vs_home_def  \
# 5437                  0.000000                                0.000000
# 5438                  0.000000                                0.392846
# 5439                  0.006144                                1.499865
# 5440                  0.004831                                0.473663
# 5441                  0.003565                                0.760592
#
#       interaction_away_form_vs_home_cards  form_vs_discipline_gap  gameresult
# 5437                             0.000000                0.000000           1
# 5438                             0.047790               -0.028571           1
# 5439                             0.070921               -0.035714           0
# 5440                             0.066536               -0.031189           0
# 5441                             0.068226               -0.002229           1
#
# [5 rows x 76 columns]

# %%
tab1 = Table1(data=df2, y="gameresult")
# Out:
# Begining analysis...
# Factorizing... please wait
# ***************************************************************************
# []
# ****************************************************************************
# ****************************************************************************
# ****************************************************************************
# []
# ------ Finished in 39.22884392738342econds -----

# %%
from IPython.display import display
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

display(tab1)
# Out:
#                                        Variables    Categories  \
# 0                                    Individuals             n
# 1                                       leagueID             1
# 2                                       leagueID             2
# 3                                       leagueID             4
# 4                                       leagueID             5
# 5                                       leagueID             3
# 6                                         season     Mean (SD)
# 7                                         season  Median (IQR)
# 9                                    home_xGoals     Mean (SD)
# 10                                   home_xGoals  Median (IQR)
# 12                                    home_shots     Mean (SD)
# 13                                    home_shots  Median (IQR)
# 15                                     home_deep     Mean (SD)
# 16                                     home_deep  Median (IQR)
# 18                                     home_ppda     Mean (SD)
# 19                                     home_ppda  Median (IQR)
# 21                                    home_fouls     Mean (SD)
# 22                                    home_fouls  Median (IQR)
# 24                           home_total_xAssists     Mean (SD)
# 25                           home_total_xAssists  Median (IQR)
# 27                         home_total_key_passes     Mean (SD)
# 28                         home_total_key_passes  Median (IQR)
# 30                        home_total_xGoalsChain     Mean (SD)
# 31                        home_total_xGoalsChain  Median (IQR)
# 33                                   away_xGoals     Mean (SD)
# 34                                   away_xGoals  Median (IQR)
# 36                                    away_shots     Mean (SD)
# 37                                    away_shots  Median (IQR)
# 39                                     away_deep     Mean (SD)
# 40                                     away_deep  Median (IQR)
# 42                                     away_ppda     Mean (SD)
# 43                                     away_ppda  Median (IQR)
# 45                                    away_fouls     Mean (SD)
# 46                                    away_fouls  Median (IQR)
# 48                           away_total_xAssists     Mean (SD)
# 49                           away_total_xAssists  Median (IQR)
# 51                         away_total_key_passes     Mean (SD)
# 52                         away_total_key_passes  Median (IQR)
# 54                        away_total_xGoalsChain     Mean (SD)
# 55                        away_total_xGoalsChain  Median (IQR)
# 57                       away_total_yellow_cards     Mean (SD)
# 58                       away_total_yellow_cards  Median (IQR)
# 60                          home_redCards_binary         False
# 61                          home_redCards_binary          True
# 62                          away_redCards_binary         False
# 63                          away_redCards_binary          True
# 64                          home_yellowCards_cat             2
# 65                          home_yellowCards_cat             1
# 66                          home_yellowCards_cat             3
# 67                          home_yellowCards_cat             0
# 68                          home_yellowCards_cat             4
# 69                          home_yellowCards_cat            5+
# 70                          away_yellowCards_cat             2
# 71                          away_yellowCards_cat             1
# 72                          away_yellowCards_cat             3
# 73                          away_yellowCards_cat             0
# 74                          away_yellowCards_cat             4
# 75                          away_yellowCards_cat            5+
# 76                        home_shotsOnTarget_cat             4
# 77                        home_shotsOnTarget_cat             3
# 78                        home_shotsOnTarget_cat             5
# 79                        home_shotsOnTarget_cat             6
# 80                        home_shotsOnTarget_cat             2
# 81                        home_shotsOnTarget_cat             7
# 82                        home_shotsOnTarget_cat         Other
# 83                        away_shotsOnTarget_cat             3
# 84                        away_shotsOnTarget_cat             4
# 85                        away_shotsOnTarget_cat             2
# 86                        away_shotsOnTarget_cat             5
# 87                        away_shotsOnTarget_cat             1
# 88                        away_shotsOnTarget_cat             6
# 89                        away_shotsOnTarget_cat         Other
# 90                              home_corners_cat             4
# 91                              home_corners_cat             5
# 92                              home_corners_cat             3
# 93                              home_corners_cat             6
# 94                              home_corners_cat             7
# 95                              home_corners_cat             2
# 96                              home_corners_cat         Other
# 97                              away_corners_cat             4
# 98                              away_corners_cat             3
# 99                              away_corners_cat             5
# 100                             away_corners_cat             2
# 101                             away_corners_cat             6
# 102                             away_corners_cat             1
# 103                             away_corners_cat         Other
# 104                 home_total_blocked_shots_cat             3
# 105                 home_total_blocked_shots_cat             2
# 106                 home_total_blocked_shots_cat             4
# 107                 home_total_blocked_shots_cat             1
# 108                 home_total_blocked_shots_cat             5
# 109                 home_total_blocked_shots_cat             6
# 110                 home_total_blocked_shots_cat         Other
# 111                 away_total_blocked_shots_cat             2
# 112                 away_total_blocked_shots_cat             1
# 113                 away_total_blocked_shots_cat             3
# 114                 away_total_blocked_shots_cat             4
# 115                 away_total_blocked_shots_cat             0
# 116                 away_total_blocked_shots_cat             5
# 117                 away_total_blocked_shots_cat         Other
# 118                   home_total_saved_shots_cat             3
# 119                   home_total_saved_shots_cat             2
# 120                   home_total_saved_shots_cat             4
# 121                   home_total_saved_shots_cat             1
# 122                   home_total_saved_shots_cat             5
# 123                   home_total_saved_shots_cat             6
# 124                   home_total_saved_shots_cat         Other
# 125                   away_total_saved_shots_cat             2
# 126                   away_total_saved_shots_cat             3
# 127                   away_total_saved_shots_cat             1
# 128                   away_total_saved_shots_cat             4
# 129                   away_total_saved_shots_cat             0
# 130                   away_total_saved_shots_cat             5
# 131                   away_total_saved_shots_cat         Other
# 132                                         year     Mean (SD)
# 133                                         year  Median (IQR)
# 135                                        month     Mean (SD)
# 136                                        month  Median (IQR)
# 138                                          day     Mean (SD)
# 139                                          day  Median (IQR)
# 141                                time_category         Night
# 142                                time_category    After Noon
# 143                                time_category          Noon
# 144                                   is_weekend          True
# 145                                   is_weekend         False
# 146                    home_cumulative_goals_for     Mean (SD)
# 147                    home_cumulative_goals_for  Median (IQR)
# 149                    away_cumulative_goals_for     Mean (SD)
# 150                    away_cumulative_goals_for  Median (IQR)
# 152                home_cumulative_goals_against     Mean (SD)
# 153                home_cumulative_goals_against  Median (IQR)
# 155                away_cumulative_goals_against     Mean (SD)
# 156                away_cumulative_goals_against  Median (IQR)
# 158                    home_cumulative_goal_diff     Mean (SD)
# 159                    home_cumulative_goal_diff  Median (IQR)
# 161                    away_cumulative_goal_diff     Mean (SD)
# 162                    away_cumulative_goal_diff  Median (IQR)
# 164                           home_avg_goals_for     Mean (SD)
# 165                           home_avg_goals_for  Median (IQR)
# 167                           away_avg_goals_for     Mean (SD)
# 168                           away_avg_goals_for  Median (IQR)
# 170                       home_avg_goals_against     Mean (SD)
# 171                       home_avg_goals_against  Median (IQR)
# 173                       away_avg_goals_against     Mean (SD)
# 174                       away_avg_goals_against  Median (IQR)
# 176                           home_goal_per_shot     Mean (SD)
# 177                           home_goal_per_shot  Median (IQR)
# 179                           away_goal_per_shot     Mean (SD)
# 180                           away_goal_per_shot  Median (IQR)
# 182                             home_goal_per_xg     Mean (SD)
# 183                             home_goal_per_xg  Median (IQR)
# 185                             away_goal_per_xg     Mean (SD)
# 186                             away_goal_per_xg  Median (IQR)
# 188                   home_rolling_goal_per_shot     Mean (SD)
# 189                   home_rolling_goal_per_shot  Median (IQR)
# 191                   away_rolling_goal_per_shot     Mean (SD)
# 192                   away_rolling_goal_per_shot  Median (IQR)
# 194                     home_rolling_goal_per_xg     Mean (SD)
# 195                     home_rolling_goal_per_xg  Median (IQR)
# 197                     away_rolling_goal_per_xg     Mean (SD)
# 198                     away_rolling_goal_per_xg  Median (IQR)
# 200                      home_blocked_shot_ratio     Mean (SD)
# 201                      home_blocked_shot_ratio  Median (IQR)
# 203                      away_blocked_shot_ratio     Mean (SD)
# 204                      away_blocked_shot_ratio  Median (IQR)
# 206                     home_shot_conceded_ratio     Mean (SD)
# 207                     home_shot_conceded_ratio  Median (IQR)
# 209                     away_shot_conceded_ratio     Mean (SD)
# 210                     away_shot_conceded_ratio  Median (IQR)
# 212                        home_discipline_score     Mean (SD)
# 213                        home_discipline_score  Median (IQR)
# 215                        away_discipline_score     Mean (SD)
# 216                        away_discipline_score  Median (IQR)
# 218                    home_discipline_score_avg     Mean (SD)
# 219                    home_discipline_score_avg  Median (IQR)
# 221                    away_discipline_score_avg     Mean (SD)
# 222                    away_discipline_score_avg  Median (IQR)
# 224                           home_adv_goal_diff     Mean (SD)
# 225                           home_adv_goal_diff  Median (IQR)
# 227                           home_adv_avg_goals     Mean (SD)
# 228                           home_adv_avg_goals  Median (IQR)
# 230                                  points_diff     Mean (SD)
# 231                                  points_diff  Median (IQR)
# 233                             recent_form_diff     Mean (SD)
# 234                             recent_form_diff  Median (IQR)
# 236              interaction_goal_rate_vs_blocks     Mean (SD)
# 237              interaction_goal_rate_vs_blocks  Median (IQR)
# 239            interaction_goal_rate_vs_conceded     Mean (SD)
# 240            interaction_goal_rate_vs_conceded  Median (IQR)
# 242  interaction_xG_efficiency_vs_shots_conceded     Mean (SD)
# 243  interaction_xG_efficiency_vs_shots_conceded  Median (IQR)
# 245                  rolling_xG_vs_shot_conceded     Mean (SD)
# 246                  rolling_xG_vs_shot_conceded  Median (IQR)
# 248                  rolling_shot_rate_vs_blocks     Mean (SD)
# 249                  rolling_shot_rate_vs_blocks  Median (IQR)
# 251                     discipline_matchup_score     Mean (SD)
# 252                     discipline_matchup_score  Median (IQR)
# 254       interaction_away_goal_rate_vs_home_def     Mean (SD)
# 255       interaction_away_goal_rate_vs_home_def  Median (IQR)
# 77     590.00 (   18.60%)    777.00 (   20.20%)    644.00 (   11.40%)    0.015
# 84     575.00 (   18.10%)    664.00 (   17.20%)    875.00 (   15.50%)    0.008
# 91     418.00 (   13.20%)    526.00 (   13.60%)    814.00 (   14.40%)    0.000
# 105    582.00 (   18.30%)    685.00 (   17.80%)  1,051.00 (   18.60%)    0.039
# 119    645.00 (   20.30%)    817.00 (   21.20%)  1,053.00 (   18.60%)    0.000
# 126    606.00 (   19.10%)    774.00 (   20.10%)  1,093.00 (   19.30%)    0.000
# 132   2,017.50 (    2.10)   2,017.60 (    2.10)   2,017.50 (    2.00)    0.001
# 142  1,307.00 (   41.20%)  1,659.00 (   43.00%)  2,312.00 (   40.90%)    0.038
# 218     -19.20 (    3.70)     -19.10 (    3.90)     -19.30 (    3.70)    0.006
# 221     -20.90 (    4.00)     -20.90 (    4.10)     -21.10 (    3.90)    0.004

# %%
# Reset to default
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')

# %%
vn1 = tab1.loc[tab1['p_value']<0.05,'Variables'].unique()
print(len(vn1))
vn1
# Out:
# 32
# array(['season', 'home_xGoals', 'home_shots', 'home_deep', 'home_ppda',
#        'home_fouls', 'home_total_xAssists', 'home_total_key_passes',
#        'home_total_xGoalsChain', 'away_xGoals', 'away_shots', 'away_deep',
#        'away_ppda', 'away_fouls', 'away_total_xAssists',
#        'away_total_key_passes', 'away_total_xGoalsChain',
#        'away_total_yellow_cards', 'home_redCards_binary',
#        'away_redCards_binary', 'home_yellowCards_cat',
#        'away_yellowCards_cat', 'home_shotsOnTarget_cat',
#        'away_shotsOnTarget_cat', 'home_corners_cat',
#        'home_total_blocked_shots_cat', 'home_total_saved_shots_cat',
#        'away_total_saved_shots_cat', 'year', 'time_category',
#        'home_discipline_score_avg', 'away_discipline_score_avg'],
#       dtype=object)

# %% [markdown]
# We will add these variables to our variable selection table

# %%
varSel['Univarable'] = 0
varSel.loc[varSel['Variable'].isin(vn1), 'Univarable'] = 1
varSel
# Out:
#                                   Variable  Univarable
# 0                                 leagueID           0
# 1                                   season           1
# 2                              home_xGoals           1
# 3                               home_shots           1
# 4                                home_deep           1
# ..                                     ...         ...
# 70             rolling_shot_rate_vs_blocks           0
# 71                discipline_matchup_score           0
# 72  interaction_away_goal_rate_vs_home_def           0
# 73     interaction_away_form_vs_home_cards           0
# 74                  form_vs_discipline_gap           0
#
# [75 rows x 2 columns]

# %% [markdown]
# # Multivariable Analysis

# %%
### drop na
df2 = df2.dropna()

# %%
# remove unnecessary vars (in this case the target variable)
X = df2.iloc[:,:-1]
X
# Out:
#       leagueID  season  home_xGoals  home_shots  home_deep  home_ppda  \
# 5437         5    2014     1.367870         9.0        2.0    31.6000
# 5438         5    2014     1.396890        14.0        2.0     5.7429
# 5439         5    2014     0.813737         9.0        3.0     7.0000
# 5440         5    2014     0.632940         6.0        3.0    16.0625
# 5441         5    2014     1.544680        14.0        5.0     3.6087
# ...        ...     ...          ...         ...        ...        ...
# 12675        5    2020     1.411190        15.0       17.0    12.3684
# 12676        5    2020     1.198190        10.0        3.0    16.2632
# 12677        5    2020     1.332690        12.0       10.0     8.2857
# 12678        5    2020     1.460500        19.0        6.0     7.5600
# 12679        5    2020     0.323960         6.0        1.0    15.1000
#
#        home_fouls  home_total_xAssists  home_total_key_passes  \
# 5437    15.000000             1.283730                    7.0
# 5438    12.597074             0.232187                    6.0
# 5439    12.000000             0.739955                    8.0
# 5440     9.000000             0.562167                    3.0
# 5441     9.000000             0.897067                    8.0
# ...           ...                  ...                    ...
# 12675    8.000000             0.971853                   11.0
# 12676   11.000000             0.855524                    8.0
# 12677   11.000000             1.151649                    8.0
# 12678   13.000000             1.265829                   13.0
# 12679   17.000000             0.074636                    4.0
#
#        home_total_xGoalsChain  ...  recent_form_diff  \
# 5437                 2.784246  ...               0.0
# 5438                 0.877201  ...               0.0
# 5439                 3.146696  ...               0.0
# 5440                 2.009705  ...               0.0
# 5441                 0.864974  ...               0.0
# ...                       ...  ...               ...
# 12675                3.853730  ...               2.0
# 12676                1.962812  ...              -1.0
# 12677                7.684589  ...              -5.0
# 12678                4.790546  ...              -1.0
# 12679                0.528499  ...               1.0
#
#        interaction_goal_rate_vs_blocks  interaction_goal_rate_vs_conceded  \
# 5437                          0.000000                           0.000000
# 5438                          0.000000                           0.000000
# 5439                          1.713977                        9523.809524
# 5440                          1.259045                           0.074073
# 5441                          0.227264                           0.040404
# ...                                ...                                ...
# 12675                         0.709173                           0.055504
# 12676                         0.305544                           0.045139
# 12677                         0.262458                           0.045931
# 12678                         0.785636                           0.040640
# 12679                         0.283861                           0.042714
#
#        interaction_xG_efficiency_vs_shots_conceded  \
# 5437                                      0.000000
# 5438                                      0.000000
# 5439                                 174392.090970
# 5440                                      1.113665
# 5441                                      0.536304
# ...                                            ...
# 12675                                     0.689314
# 12676                                     0.538391
# 12677                                     0.563541
# 12678                                     0.485981
# 12679                                     0.472708
#
#        rolling_xG_vs_shot_conceded  rolling_shot_rate_vs_blocks  \
# 5437                      0.000000                     0.000000
# 5438                      0.000000                     0.000000
# 5439                      0.000000                     0.000000
# 5440                      0.000000                     0.000000
# 5441                      0.000000                     0.000000
# ...                            ...                          ...
# 12675                     5.982849                     0.833278
# 12676                     1.407168                     0.271595
# 12677                     0.914720                     0.064100
# 12678                     0.356758                     0.175421
# 12679                     0.827011                     0.112816
#
#        discipline_matchup_score  interaction_away_goal_rate_vs_home_def  \
# 5437                   0.000000                                0.000000
# 5438                   0.000000                                0.392846
# 5439                   0.006144                                1.499865
# 5440                   0.004831                                0.473663
# 5441                   0.003565                                0.760592
# ...                         ...                                     ...
# 12675                  0.005526                                0.366958
# 12676                  0.004440                                0.051354
# 12677                  0.004306                                0.859289
# 12678                  0.004414                                0.401440
# 12679                  0.004301                                0.073333
#
#        interaction_away_form_vs_home_cards form_vs_discipline_gap
# 5437                              0.000000               0.000000
# 5438                              0.047790              -0.028571
# 5439                              0.070921              -0.035714
# 5440                              0.066536              -0.031189
# 5441                              0.068226              -0.002229
# ...                                    ...                    ...
# 12675                             0.062061               0.002703
# 12676                             0.062261              -0.002233
# 12677                             0.057900              -0.002056
# 12678                             0.054791              -0.000600
# 12679                             0.051097               0.001595
#
# [12680 rows x 75 columns]

# %%
y = df2.iloc[:,-1:]
print([X.shape,y.shape])
# Out:
# [(12680, 75), (12680, 1)]

# %% [markdown]
# ## Variable Selection using LASSO (L1 penalization)

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
# Step 0: X = full feature dataframe, y = target
X_encoded = X.copy()

# Step 1: Encode categorical columns using .cat.codes
for col in X_encoded.select_dtypes(include=['category', 'object']).columns:
    X_encoded[col] = X_encoded[col].astype('category').cat.codes

# Step 2: Drop datetime columns if still present
X_encoded = X_encoded.drop(columns=[
    col for col in X_encoded.columns 
    if np.issubdtype(X_encoded[col].dtype, np.datetime64)
], errors='ignore')

# Step 3: Handle missing values
X_encoded = X_encoded.dropna()  # or use .fillna(method='ffill') or .fillna(0)

# Step 4: Align y
y_clean = y.loc[X_encoded.index]

# Step 5: Scale features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_encoded)

# %%
X = X_scaled
y = y_clean

# %%
lassomod = Lasso(alpha=0.01).fit(X, y)

# %%
model = SelectFromModel(lassomod, prefit=True)
model.get_support()
# Out:
# array([False,  True,  True, False, False,  True, False,  True, False,
#         True,  True, False,  True,  True, False,  True, False,  True,
#        False,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True, False,
#        False, False,  True, False, False, False, False, False, False,
#        False,  True, False, False, False, False,  True,  True, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
print("Features in varSel but not in model:")
print(set(varSel['Variable']) - set(X_encoded.columns))

print("Features in model but not in varSel:")
print(set(X_encoded.columns) - set(varSel['Variable']))
# Out:
# Features in varSel but not in model:
# set()
# Features in model but not in varSel:
# set()

# %%
X_model_input = X_encoded.copy()  # after cleaning, encoding, dropping nulls

# %%
# Re-train Lasso using the correct input
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_model_input)

from sklearn.linear_model import Lasso
lasso = Lasso(alpha=0.01)
lasso.fit(X_scaled, y_clean)
# Out:
# Lasso(alpha=0.01)

# %%
selected_features = X_model_input.columns[lasso.coef_ != 0]
varSel['Lasso'] = varSel['Variable'].isin(selected_features).astype(int)

# %%
selected_features = X_model_input.columns[model.get_support()]

# %%
varSel['Lasso'] = varSel['Variable'].isin(selected_features).astype('int64')

# %%
varSel[varSel['Lasso'] == 1]
# Out:
#                         Variable  Univarable  Lasso
# 1                         season           1      1
# 2                    home_xGoals           1      1
# 5                      home_ppda           1      1
# 7            home_total_xAssists           1      1
# 9         home_total_xGoalsChain           1      1
# 10                   away_xGoals           1      1
# 12                     away_deep           1      1
# 13                     away_ppda           1      1
# 15           away_total_xAssists           1      1
# 17        away_total_xGoalsChain           1      1
# 19          home_redCards_binary           1      1
# 20          away_redCards_binary           1      1
# 21          home_yellowCards_cat           1      1
# 23        home_shotsOnTarget_cat           1      1
# 24        away_shotsOnTarget_cat           1      1
# 25              home_corners_cat           1      1
# 26              away_corners_cat           0      1
# 27  home_total_blocked_shots_cat           1      1
# 28  away_total_blocked_shots_cat           0      1
# 29    home_total_saved_shots_cat           1      1
# 30    away_total_saved_shots_cat           1      1
# 43            away_avg_goals_for           0      1
# 47            away_goal_per_shot           0      1
# 55       away_blocked_shot_ratio           0      1
# 60     home_discipline_score_avg           1      1
# 61     away_discipline_score_avg           1      1

# %%
varSel['Lasso'].sum()
# Out:
# 26

# %%
varSel[(varSel['Lasso'] == 1) & (varSel['Univarable'] == 1)]
# Out:
#                         Variable  Univarable  Lasso
# 1                         season           1      1
# 2                    home_xGoals           1      1
# 5                      home_ppda           1      1
# 7            home_total_xAssists           1      1
# 9         home_total_xGoalsChain           1      1
# 10                   away_xGoals           1      1
# 12                     away_deep           1      1
# 13                     away_ppda           1      1
# 15           away_total_xAssists           1      1
# 17        away_total_xGoalsChain           1      1
# 19          home_redCards_binary           1      1
# 20          away_redCards_binary           1      1
# 21          home_yellowCards_cat           1      1
# 23        home_shotsOnTarget_cat           1      1
# 24        away_shotsOnTarget_cat           1      1
# 25              home_corners_cat           1      1
# 27  home_total_blocked_shots_cat           1      1
# 29    home_total_saved_shots_cat           1      1
# 30    away_total_saved_shots_cat           1      1
# 60     home_discipline_score_avg           1      1
# 61     away_discipline_score_avg           1      1

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.linear_model import Lasso

# Step 1: Create Lasso and wrap it in SelectFromModel
lasso_base = Lasso(alpha=0.01)
model = SelectFromModel(estimator=lasso_base)

# Step 2: Fit the SelectFromModel on your scaled features
model.fit(X_scaled, y_clean)

# Step 3: Now safely access the fitted Lasso
lasso_model = model.estimator_

# Step 4: Get the Lasso coefficients
lasso_result = pd.Series(lasso_model.coef_, index=X_model_input.columns)
lasso_selected = lasso_result[lasso_result != 0].sort_values(key=abs, ascending=False)
lasso_selected
# Out:
# away_shotsOnTarget_cat         -0.251611
# away_xGoals                    -0.213200
# home_xGoals                     0.204621
# away_total_saved_shots_cat      0.204379
# home_shotsOnTarget_cat          0.152177
# home_total_saved_shots_cat     -0.122075
# home_total_xGoalsChain          0.118825
# home_total_blocked_shots_cat   -0.084629
# away_total_xGoalsChain         -0.079226
# away_total_blocked_shots_cat    0.061256
# away_redCards_binary            0.035461
# home_redCards_binary           -0.029385
# away_total_xAssists            -0.020710
# away_corners_cat                0.020273
# home_ppda                       0.019524
# home_total_xAssists             0.017003
# home_yellowCards_cat           -0.016002
# away_ppda                      -0.011499
# home_corners_cat               -0.006631
# away_deep                       0.002741
# away_discipline_score_avg      -0.002177
# away_blocked_shot_ratio         0.001514
# away_avg_goals_for              0.001358
# home_discipline_score_avg      -0.000320
# away_goal_per_shot              0.000051
# season                         -0.000048
# dtype: float64

# %%
lasso_selected.plot(kind='barh', figsize=(10, 8))
plt.title("Lasso Selected Feature Coefficients")
plt.xlabel("Coefficient")
plt.ylabel("Feature")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Variable Selection using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel

rfmod = RandomForestClassifier().fit(X_scaled, y_clean)
#rfmod.feature_importances_

# %%
model = SelectFromModel(rfmod, prefit=True)
model.get_support()
# Out:
# array([False, False,  True, False, False,  True, False,  True, False,
#         True,  True, False, False,  True, False,  True, False,  True,
#        False, False, False, False, False,  True,  True, False, False,
#        False, False,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
selected_rf_features = X_model_input.columns[model.get_support()]

# %%
varSel['RandomForest'] = varSel['Variable'].isin(selected_rf_features).astype('int64')

# %%
varSel[varSel['RandomForest'] == 1]
# Out:
#                       Variable  Univarable  Lasso  RandomForest
# 2                  home_xGoals           1      1             1
# 5                    home_ppda           1      1             1
# 7          home_total_xAssists           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 13                   away_ppda           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1

# %%
varSel['RandomForest'].sum()
# Out:
# 12

# %%
# Intersection with Lasso
display(varSel[(varSel['RandomForest'] == 1) & (varSel['Lasso'] == 1)])

# Triple intersection: RF + Lasso + Univariate
display(varSel[(varSel['RandomForest'] == 1) & (varSel['Lasso'] == 1) & (varSel['Univarable'] == 1)])
# Out:
#                       Variable  Univarable  Lasso  RandomForest
# 2                  home_xGoals           1      1             1
# 5                    home_ppda           1      1             1
# 7          home_total_xAssists           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 13                   away_ppda           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1
#                       Variable  Univarable  Lasso  RandomForest
# 2                  home_xGoals           1      1             1
# 5                    home_ppda           1      1             1
# 7          home_total_xAssists           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 13                   away_ppda           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1

# %%
rf = RandomForestClassifier(random_state=42)
model = SelectFromModel(estimator=rf)
model.fit(X_scaled, y_clean)
# Out:
# SelectFromModel(estimator=RandomForestClassifier(random_state=42))

# %%
importances = pd.Series(model.estimator_.feature_importances_, index=X_model_input.columns)
importances = importances[importances != 0].sort_values(ascending=False)
importances.head(20)
# Out:
# home_xGoals                               0.061593
# away_xGoals                               0.054900
# away_total_xAssists                       0.044632
# away_total_xGoalsChain                    0.039184
# home_total_xAssists                       0.038754
# home_total_xGoalsChain                    0.033853
# away_shotsOnTarget_cat                    0.025163
# home_shotsOnTarget_cat                    0.025105
# home_ppda                                 0.018099
# away_ppda                                 0.016552
# home_total_saved_shots_cat                0.015028
# away_total_saved_shots_cat                0.014042
# interaction_away_goal_rate_vs_home_def    0.012840
# form_vs_discipline_gap                    0.012630
# away_discipline_score_avg                 0.012407
# away_goal_per_xg                          0.012092
# interaction_goal_rate_vs_blocks           0.012089
# rolling_xG_vs_shot_conceded               0.012045
# rolling_shot_rate_vs_blocks               0.011959
# home_rolling_goal_per_xg                  0.011932
# dtype: float64

# %%
importances.head(20).plot(kind='barh', figsize=(10, 6))
plt.title("Top 20 Random Forest Feature Importances")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Variable Selection using Gradient Boosting classification

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.feature_selection import SelectFromModel

# %%
gbmod = GradientBoostingClassifier().fit(X_scaled, y_clean)

# %%
model = SelectFromModel(gbmod, prefit=True)
model.get_support()
# Out:
# array([False, False,  True, False, False, False, False, False, False,
#         True,  True, False, False, False, False,  True, False,  True,
#        False, False, False, False, False,  True,  True, False, False,
#         True, False,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False])

# %%
selected_gb_features = X_model_input.columns[model.get_support()]

# %%
varSel['GradienBoosting'] = varSel['Variable'].isin(selected_gb_features).astype('int64')

# %%
varSel[varSel['GradienBoosting'] == 1]
# Out:
#                         Variable  Univarable  Lasso  RandomForest  \
# 2                    home_xGoals           1      1             1
# 9         home_total_xGoalsChain           1      1             1
# 10                   away_xGoals           1      1             1
# 15           away_total_xAssists           1      1             1
# 17        away_total_xGoalsChain           1      1             1
# 23        home_shotsOnTarget_cat           1      1             1
# 24        away_shotsOnTarget_cat           1      1             1
# 27  home_total_blocked_shots_cat           1      1             0
# 29    home_total_saved_shots_cat           1      1             1
# 30    away_total_saved_shots_cat           1      1             1
#
#     GradienBoosting
# 2                 1
# 9                 1
# 10                1
# 15                1
# 17                1
# 23                1
# 24                1
# 27                1
# 29                1
# 30                1

# %%
varSel['GradienBoosting'].sum()
# Out:
# 10

# %%
# Lasso & GB
display(varSel[(varSel['GradienBoosting'] == 1) & (varSel['Lasso'] == 1)])

# GB & Random Forest
display(varSel[(varSel['GradienBoosting'] == 1) & (varSel['RandomForest'] == 1)])

# Lasso & RF & GB
display(varSel[(varSel['GradienBoosting'] == 1) & 
       (varSel['RandomForest'] == 1) & 
       (varSel['Lasso'] == 1)])

# All 4: GB + RF + Lasso + Univariate
display(varSel[(varSel['GradienBoosting'] == 1) &
       (varSel['RandomForest'] == 1) &
       (varSel['Lasso'] == 1) &
       (varSel['Univarable'] == 1)])
# Out:
#                         Variable  Univarable  Lasso  RandomForest  \
# 2                    home_xGoals           1      1             1
# 9         home_total_xGoalsChain           1      1             1
# 10                   away_xGoals           1      1             1
# 15           away_total_xAssists           1      1             1
# 17        away_total_xGoalsChain           1      1             1
# 23        home_shotsOnTarget_cat           1      1             1
# 24        away_shotsOnTarget_cat           1      1             1
# 27  home_total_blocked_shots_cat           1      1             0
# 29    home_total_saved_shots_cat           1      1             1
# 30    away_total_saved_shots_cat           1      1             1
#
#     GradienBoosting
# 2                 1
# 9                 1
# 10                1
# 15                1
# 17                1
# 23                1
# 24                1
# 27                1
# 29                1
# 30                1
#                       Variable  Univarable  Lasso  RandomForest  \
# 2                  home_xGoals           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1
#
#     GradienBoosting
# 2                 1
# 9                 1
# 10                1
# 15                1
# 17                1
# 23                1
# 24                1
# 29                1
# 30                1
#                       Variable  Univarable  Lasso  RandomForest  \
# 2                  home_xGoals           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1
#
#     GradienBoosting
# 2                 1
# 9                 1
# 10                1
# 15                1
# 17                1
# 23                1
# 24                1
# 29                1
# 30                1
#                       Variable  Univarable  Lasso  RandomForest  \
# 2                  home_xGoals           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1
#
#     GradienBoosting
# 2                 1
# 9                 1
# 10                1
# 15                1
# 17                1
# 23                1
# 24                1
# 29                1
# 30                1

# %%
gb = GradientBoostingClassifier(random_state=42)
model = SelectFromModel(estimator=gb)
model.fit(X_scaled, y_clean)
# Out:
# SelectFromModel(estimator=GradientBoostingClassifier(random_state=42))

# %%
importances = pd.Series(model.estimator_.feature_importances_, index=X_model_input.columns)
importances = importances[importances != 0].sort_values(ascending=False)
importances.head(20)
# Out:
# home_xGoals                     0.171703
# away_xGoals                     0.167973
# home_shotsOnTarget_cat          0.151954
# away_shotsOnTarget_cat          0.126674
# home_total_saved_shots_cat      0.117244
# away_total_saved_shots_cat      0.115872
# home_total_xGoalsChain          0.036161
# away_total_xGoalsChain          0.023586
# away_total_xAssists             0.017295
# home_total_blocked_shots_cat    0.013592
# home_total_xAssists             0.008957
# home_ppda                       0.007274
# away_total_blocked_shots_cat    0.005739
# away_ppda                       0.003026
# home_yellowCards_cat            0.002337
# home_shots                      0.001887
# home_corners_cat                0.001595
# away_fouls                      0.001350
# form_vs_discipline_gap          0.001189
# away_rolling_goal_per_shot      0.001101
# dtype: float64

# %%
importances.head(20).plot(kind='barh', figsize=(10, 6))
plt.title("Top 20 Gradient Boosting Feature Importances")
plt.xlabel("Importance")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Variable Selection using SVM classification

# %%
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel

svmmod = LinearSVC(C=0.01, penalty="l1",dual=False).fit(X, y)

# %%
model = SelectFromModel(svmmod, prefit=True)
model.get_support()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#        False, False, False, False, False,  True, False,  True, False,
#         True,  True, False, False,  True, False,  True, False,  True,
#        False,  True,  True,  True,  True, False,  True,  True,  True,
#         True, False,  True,  True,  True, False,  True,  True, False,
#        False,  True,  True])

# %%
selected_svm_features = X_model_input.columns[model.get_support()]

# %%
varSel['SVM'] = varSel['Variable'].isin(selected_svm_features).astype('int64')

# %%
varSel[varSel['SVM'] == 1]
# Out:
#                                Variable  Univarable  Lasso  RandomForest  \
# 0                              leagueID           0      0             0
# 1                                season           1      1             0
# 2                           home_xGoals           1      1             1
# 3                            home_shots           1      0             0
# 4                             home_deep           1      0             0
# 5                             home_ppda           1      1             1
# 6                            home_fouls           1      0             0
# 7                   home_total_xAssists           1      1             1
# 8                 home_total_key_passes           1      0             0
# 9                home_total_xGoalsChain           1      1             1
# 10                          away_xGoals           1      1             1
# 11                           away_shots           1      0             0
# 12                            away_deep           1      1             0
# 13                            away_ppda           1      1             1
# 14                           away_fouls           1      0             0
# 15                  away_total_xAssists           1      1             1
# 16                away_total_key_passes           1      0             0
# 17               away_total_xGoalsChain           1      1             1
# 18              away_total_yellow_cards           1      0             0
# 19                 home_redCards_binary           1      1             0
# 20                 away_redCards_binary           1      1             0
# 21                 home_yellowCards_cat           1      1             0
# 22                 away_yellowCards_cat           1      0             0
# 23               home_shotsOnTarget_cat           1      1             1
# 24               away_shotsOnTarget_cat           1      1             1
# 25                     home_corners_cat           1      1             0
# 26                     away_corners_cat           0      1             0
# 27         home_total_blocked_shots_cat           1      1             0
# 28         away_total_blocked_shots_cat           0      1             0
# 29           home_total_saved_shots_cat           1      1             1
# 30           away_total_saved_shots_cat           1      1             1
# 32                                month           0      0             0
# 33                                  day           0      0             0
# 34                        time_category           1      0             0
# 35                           is_weekend           0      0             0
# 41            away_cumulative_goal_diff           0      0             0
# 43                   away_avg_goals_for           0      1             0
# 45               away_avg_goals_against           0      0             0
# 46                   home_goal_per_shot           0      0             0
# 49                     away_goal_per_xg           0      0             0
# 51           away_rolling_goal_per_shot           0      0             0
# 53             away_rolling_goal_per_xg           0      0             0
# 55              away_blocked_shot_ratio           0      1             0
# 56             home_shot_conceded_ratio           0      0             0
# 57             away_shot_conceded_ratio           0      0             0
# 58                home_discipline_score           0      0             0
# 60            home_discipline_score_avg           1      1             0
# 61            away_discipline_score_avg           1      1             0
# 62                   home_adv_goal_diff           0      0             0
# 63                   home_adv_avg_goals           0      0             0
# 65                     recent_form_diff           0      0             0
# 66      interaction_goal_rate_vs_blocks           0      0             0
# 67    interaction_goal_rate_vs_conceded           0      0             0
# 69          rolling_xG_vs_shot_conceded           0      0             0
# 70          rolling_shot_rate_vs_blocks           0      0             0
# 73  interaction_away_form_vs_home_cards           0      0             0
# 74               form_vs_discipline_gap           0      0             0
#
#     GradienBoosting  SVM
# 0                 0    1
# 1                 0    1
# 2                 1    1
# 3                 0    1
# 4                 0    1
# 5                 0    1
# 6                 0    1
# 7                 0    1
# 8                 0    1
# 9                 1    1
# 10                1    1
# 11                0    1
# 12                0    1
# 13                0    1
# 14                0    1
# 15                1    1
# 16                0    1
# 17                1    1
# 18                0    1
# 19                0    1
# 20                0    1
# 21                0    1
# 22                0    1
# 23                1    1
# 24                1    1
# 25                0    1
# 26                0    1
# 27                1    1
# 28                0    1
# 29                1    1
# 30                1    1
# 32                0    1
# 33                0    1
# 34                0    1
# 35                0    1
# 41                0    1
# 43                0    1
# 45                0    1
# 46                0    1
# 49                0    1
# 51                0    1
# 53                0    1
# 55                0    1
# 56                0    1
# 57                0    1
# 58                0    1
# 60                0    1
# 61                0    1
# 62                0    1
# 63                0    1
# 65                0    1
# 66                0    1
# 67                0    1
# 69                0    1
# 70                0    1
# 73                0    1
# 74                0    1

# %%
varSel['SVM'].sum()
# Out:
# 57

# %%
# Get absolute value of coefficients (shape: [n_classes, n_features])
coefs = np.abs(svmmod.coef_)  # shape: (n_classes, n_features)

# Reduce to one score per feature — use max or sum across classes
reduced_coefs = coefs.max(axis=0)  # or .sum(axis=0)

# Now match to column names
selected_svm_features = X_model_input.columns[reduced_coefs != 0]

# %%
svm_result = pd.Series(reduced_coefs, index=X_model_input.columns)
svm_result = svm_result[svm_result != 0].sort_values(ascending=False)
svm_result.head(20)
# Out:
# away_shotsOnTarget_cat          0.361297
# away_xGoals                     0.296228
# away_total_saved_shots_cat      0.286459
# home_xGoals                     0.279446
# home_shotsOnTarget_cat          0.227920
# home_total_xGoalsChain          0.223001
# home_total_saved_shots_cat      0.193461
# home_total_blocked_shots_cat    0.132942
# away_total_xGoalsChain          0.121595
# away_total_blocked_shots_cat    0.107612
# home_redCards_binary            0.053076
# away_redCards_binary            0.052063
# home_yellowCards_cat            0.046686
# away_total_xAssists             0.046300
# home_ppda                       0.035631
# away_shots                      0.035344
# away_total_key_passes           0.032784
# away_corners_cat                0.031797
# away_deep                       0.027997
# away_fouls                      0.020589
# dtype: float64

# %%
# Plot top 20 SVM feature importances
svm_result.head(20).plot(kind='barh', figsize=(10, 6))
plt.title("Top 20 Feature Importances from SVM (L1)")
plt.xlabel("Absolute Coefficient (Importance)")
plt.ylabel("Feature")
plt.gca().invert_yaxis()  # So highest is on top
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summarization and Selection of Variables

# %%
varSel['Sum'] =  np.sum(varSel,axis=1)
varSel
# Out:
#                                   Variable  Univarable  Lasso  RandomForest  \
# 0                                 leagueID           0      0             0
# 1                                   season           1      1             0
# 2                              home_xGoals           1      1             1
# 3                               home_shots           1      0             0
# 4                                home_deep           1      0             0
# ..                                     ...         ...    ...           ...
# 70             rolling_shot_rate_vs_blocks           0      0             0
# 71                discipline_matchup_score           0      0             0
# 72  interaction_away_goal_rate_vs_home_def           0      0             0
# 73     interaction_away_form_vs_home_cards           0      0             0
# 74                  form_vs_discipline_gap           0      0             0
#
#     GradienBoosting  SVM  Sum
# 0                 0    1    1
# 1                 0    1    3
# 2                 1    1    5
# 3                 0    1    2
# 4                 0    1    2
# ..              ...  ...  ...
# 70                0    1    1
# 71                0    0    0
# 72                0    0    0
# 73                0    1    1
# 74                0    1    1
#
# [75 rows x 7 columns]

# %%
varSel.groupby('Sum')['Variable'].count()
# Out:
# Sum
# 0    16
# 1    24
# 2    14
# 3     8
# 4     4
# 5     9
# Name: Variable, dtype: int64

# %%
varSel[varSel['Sum']==5]
# Out:
#                       Variable  Univarable  Lasso  RandomForest  \
# 2                  home_xGoals           1      1             1
# 9       home_total_xGoalsChain           1      1             1
# 10                 away_xGoals           1      1             1
# 15         away_total_xAssists           1      1             1
# 17      away_total_xGoalsChain           1      1             1
# 23      home_shotsOnTarget_cat           1      1             1
# 24      away_shotsOnTarget_cat           1      1             1
# 29  home_total_saved_shots_cat           1      1             1
# 30  away_total_saved_shots_cat           1      1             1
#
#     GradienBoosting  SVM  Sum
# 2                 1    1    5
# 9                 1    1    5
# 10                1    1    5
# 15                1    1    5
# 17                1    1    5
# 23                1    1    5
# 24                1    1    5
# 29                1    1    5
# 30                1    1    5

# %%
varSel[varSel['Sum']==3]
# Out:
#                      Variable  Univarable  Lasso  RandomForest  \
# 1                      season           1      1             0
# 12                  away_deep           1      1             0
# 19       home_redCards_binary           1      1             0
# 20       away_redCards_binary           1      1             0
# 21       home_yellowCards_cat           1      1             0
# 25           home_corners_cat           1      1             0
# 60  home_discipline_score_avg           1      1             0
# 61  away_discipline_score_avg           1      1             0
#
#     GradienBoosting  SVM  Sum
# 1                 0    1    3
# 12                0    1    3
# 19                0    1    3
# 20                0    1    3
# 21                0    1    3
# 25                0    1    3
# 60                0    1    3
# 61                0    1    3

# %%
varSel[varSel['Sum']>=3]
# Out:
#                         Variable  Univarable  Lasso  RandomForest  \
# 1                         season           1      1             0
# 2                    home_xGoals           1      1             1
# 5                      home_ppda           1      1             1
# 7            home_total_xAssists           1      1             1
# 9         home_total_xGoalsChain           1      1             1
# 10                   away_xGoals           1      1             1
# 12                     away_deep           1      1             0
# 13                     away_ppda           1      1             1
# 15           away_total_xAssists           1      1             1
# 17        away_total_xGoalsChain           1      1             1
# 19          home_redCards_binary           1      1             0
# 20          away_redCards_binary           1      1             0
# 21          home_yellowCards_cat           1      1             0
# 23        home_shotsOnTarget_cat           1      1             1
# 24        away_shotsOnTarget_cat           1      1             1
# 25              home_corners_cat           1      1             0
# 27  home_total_blocked_shots_cat           1      1             0
# 29    home_total_saved_shots_cat           1      1             1
# 30    away_total_saved_shots_cat           1      1             1
# 60     home_discipline_score_avg           1      1             0
# 61     away_discipline_score_avg           1      1             0
#
#     GradienBoosting  SVM  Sum
# 1                 0    1    3
# 2                 1    1    5
# 5                 0    1    4
# 7                 0    1    4
# 9                 1    1    5
# 10                1    1    5
# 12                0    1    3
# 13                0    1    4
# 15                1    1    5
# 17                1    1    5
# 19                0    1    3
# 20                0    1    3
# 21                0    1    3
# 23                1    1    5
# 24                1    1    5
# 25                0    1    3
# 27                1    1    4
# 29                1    1    5
# 30                1    1    5
# 60                0    1    3
# 61                0    1    3

# %%
varSel[varSel['Sum']>=2]
# Out:
#                         Variable  Univarable  Lasso  RandomForest  \
# 1                         season           1      1             0
# 2                    home_xGoals           1      1             1
# 3                     home_shots           1      0             0
# 4                      home_deep           1      0             0
# 5                      home_ppda           1      1             1
# 6                     home_fouls           1      0             0
# 7            home_total_xAssists           1      1             1
# 8          home_total_key_passes           1      0             0
# 9         home_total_xGoalsChain           1      1             1
# 10                   away_xGoals           1      1             1
# 11                    away_shots           1      0             0
# 12                     away_deep           1      1             0
# 13                     away_ppda           1      1             1
# 14                    away_fouls           1      0             0
# 15           away_total_xAssists           1      1             1
# 16         away_total_key_passes           1      0             0
# 17        away_total_xGoalsChain           1      1             1
# 18       away_total_yellow_cards           1      0             0
# 19          home_redCards_binary           1      1             0
# 20          away_redCards_binary           1      1             0
# 21          home_yellowCards_cat           1      1             0
# 22          away_yellowCards_cat           1      0             0
# 23        home_shotsOnTarget_cat           1      1             1
# 24        away_shotsOnTarget_cat           1      1             1
# 25              home_corners_cat           1      1             0
# 26              away_corners_cat           0      1             0
# 27  home_total_blocked_shots_cat           1      1             0
# 28  away_total_blocked_shots_cat           0      1             0
# 29    home_total_saved_shots_cat           1      1             1
# 30    away_total_saved_shots_cat           1      1             1
# 34                 time_category           1      0             0
# 43            away_avg_goals_for           0      1             0
# 55       away_blocked_shot_ratio           0      1             0
# 60     home_discipline_score_avg           1      1             0
# 61     away_discipline_score_avg           1      1             0
#
#     GradienBoosting  SVM  Sum
# 1                 0    1    3
# 2                 1    1    5
# 3                 0    1    2
# 4                 0    1    2
# 5                 0    1    4
# 6                 0    1    2
# 7                 0    1    4
# 8                 0    1    2
# 9                 1    1    5
# 10                1    1    5
# 11                0    1    2
# 12                0    1    3
# 13                0    1    4
# 14                0    1    2
# 15                1    1    5
# 16                0    1    2
# 17                1    1    5
# 18                0    1    2
# 19                0    1    3
# 20                0    1    3
# 21                0    1    3
# 22                0    1    2
# 23                1    1    5
# 24                1    1    5
# 25                0    1    3
# 26                0    1    2
# 27                1    1    4
# 28                0    1    2
# 29                1    1    5
# 30                1    1    5
# 34                0    1    2
# 43                0    1    2
# 55                0    1    2
# 60                0    1    3
# 61                0    1    3

# %%
type(varSel)
# Out:
# pandas.core.frame.DataFrame

# %%
final_var = varSel[varSel['Sum']>=3]['Variable'].tolist()
df_model = df[final_var].copy()
## add our Y 
df_model['gameresult'] = df['gameresult'].copy()

# %%
df_model.shape
# Out:
# (12680, 22)

# %%
df_model.to_csv('../csvs/df_model.csv')

# %%
# saving df for modeling
with open("../pickles/df_model.pkl", "wb") as f:
    pickle.dump(df_model, f)  # Save the DataFrame with standard pickle

# %% [markdown]
# ## Setting proportion for Train, Test, Dev

# %%
from pyMechkar.analysis import train_test

# %%
train, temp = train_test(df_model, prop=0.6, seed=18)
# Out:
# Begining analysis...
# Factorizing... please wait
# **********************
# []
# ***********************
# ***********************
# []
# ------ Finished in 8.888408184051514econds -----
#
# You got a perfectly balanced training and test datasets

# %%
#60%
train.shape
# Out:
# (7608, 23)

# %%
df_object_train =  train.select_dtypes(include = ['object']).columns

# %% [markdown]
# ## Encoding Categorial Data

# %%
# Select all categorical columns: both object and category
cat_cols = train.select_dtypes(include=['object', 'category']).columns

# Encode all of them
from sklearn.preprocessing import OrdinalEncoder

ord_enc = OrdinalEncoder()
train[cat_cols] = ord_enc.fit_transform(train[cat_cols])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7608 entries, 8859 to 11119
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   season                        7608 non-null   int64
#  1   home_xGoals                   7608 non-null   float64
#  2   home_ppda                     7608 non-null   float64
#  3   home_total_xAssists           7608 non-null   float64
#  4   home_total_xGoalsChain        7608 non-null   float64
#  5   away_xGoals                   7608 non-null   float64
#  6   away_deep                     7608 non-null   float64
#  7   away_ppda                     7608 non-null   float64
#  8   away_total_xAssists           7608 non-null   float64
#  9   away_total_xGoalsChain        7608 non-null   float64
#  10  home_redCards_binary          7608 non-null   bool
#  11  away_redCards_binary          7608 non-null   bool
#  12  home_yellowCards_cat          7608 non-null   float64
#  13  home_shotsOnTarget_cat        7608 non-null   float64
#  14  away_shotsOnTarget_cat        7608 non-null   float64
#  15  home_corners_cat              7608 non-null   float64
#  16  home_total_blocked_shots_cat  7608 non-null   float64
#  17  home_total_saved_shots_cat    7608 non-null   float64
#  18  away_total_saved_shots_cat    7608 non-null   float64
#  19  home_discipline_score_avg     7608 non-null   float64
#  20  away_discipline_score_avg     7608 non-null   float64
#  21  gameresult                    7608 non-null   int64
#  22  split                         7608 non-null   float64
# dtypes: bool(2), float64(19), int64(2)
# memory usage: 1.3 MB

# %%
train.to_csv('../csvs/Football_Database_train.csv')

# %%
# saving df after finishing feature engineering
with open("../pickles/train.pkl", "wb") as f:
    pickle.dump(train, f)  # Save the DataFrame with standard pickle

# %%
dev, test = train_test(temp, prop=0.5, seed=18)
# Out:
# Begining analysis...
# Factorizing... please wait
# **********************
# []
# ***********************
# ***********************
# []
# ------ Finished in 8.338094234466553econds -----
#
# You got a perfectly balanced training and test datasets

# %%
# Select all categorical columns: both object and category
cat_cols_test = test.select_dtypes(include=['object', 'category']).columns

ord_enc_test = OrdinalEncoder()
test[cat_cols] = ord_enc.fit_transform(test[cat_cols])

# Select all categorical columns: both object and category
cat_cols_dev = dev.select_dtypes(include=['object', 'category']).columns

ord_enc_dev = OrdinalEncoder()
dev[cat_cols] = ord_enc.fit_transform(dev[cat_cols])

# %%
#50%
test.shape
# Out:
# (2536, 23)

# %%
test.to_csv('../csvs/Football_Database_test.csv')

# saving df after finishing feature engineering
with open("../pickles/test.pkl", "wb") as f:
    pickle.dump(test, f)  # Save the DataFrame with standard pickle

# %%
test
# Out:
#        season  home_xGoals  home_ppda  home_total_xAssists  \
# 9123     2018     1.354740     6.1111             1.182628
# 809      2015     1.030380     2.2500             0.634875
# 780      2015     0.744526     7.5758             0.541279
# 265      2015     2.074880    10.8571             1.528366
# 12190    2020     1.754310     3.3704             1.073796
# ...       ...          ...        ...                  ...
# 4626     2014     1.495350    10.6190             0.552496
# 11262    2020     1.474980     7.6000             1.323135
# 3731     2014     0.600074    10.0000             0.570147
# 439      2016     0.569734    10.9583             0.522914
# 1827     2015     0.135570    20.4286             0.082793
#
#        home_total_xGoalsChain  away_xGoals  away_deep  away_ppda  \
# 9123                 1.025618     0.484752   5.000000    10.8800
# 809                  2.760650     0.263110   2.000000    12.7333
# 780                  1.120400     1.413000   9.000000     6.0476
# 265                  5.236435     1.216380   3.000000     8.1000
# 12190                4.081372     0.547118   4.000000    23.8000
# ...                       ...          ...        ...        ...
# 4626                 3.685556     3.363920   3.000000    12.4615
# 11262                1.247887     1.407060   6.000000     4.7647
# 3731                 2.078904     1.517170   4.824998    11.6923
# 439                  0.855076     0.776105   1.000000     9.6111
# 1827                 0.114885     2.136190  13.000000    10.1250
#
#        away_total_xAssists  away_total_xGoalsChain  ...  \
# 9123              0.305696                0.905245  ...
# 809               0.205247                0.577086  ...
# 780               0.865091                4.211229  ...
# 265               0.934175                1.840798  ...
# 12190             0.504012                0.899477  ...
# ...                    ...                     ...  ...
# 4626              2.898960                4.809696  ...
# 11262             1.253420                3.484246  ...
# 3731              0.677178                2.772529  ...
# 439               0.545509                1.371013  ...
# 1827              2.141013               12.789631  ...
#
#        home_shotsOnTarget_cat  away_shotsOnTarget_cat  home_corners_cat  \
# 9123                      5.0                     6.0              10.0
# 809                       5.0                     4.0               7.0
# 780                       4.0                     5.0               7.0
# 265                       7.0                     4.0               6.0
# 12190                    10.0                     4.0               2.0
# ...                       ...                     ...               ...
# 4626                      8.0                    11.0              12.0
# 11262                     8.0                     6.0               4.0
# 3731                      4.0                     6.0               5.0
# 439                       6.0                     4.0              10.0
# 1827                      4.0                    10.0               6.0
#
#        home_total_blocked_shots_cat  home_total_saved_shots_cat  \
# 9123                            3.0                         2.0
# 809                             9.0                         3.0
# 780                             6.0                         2.0
# 265                             1.0                         2.0
# 12190                           9.0                         7.0
# ...                             ...                         ...
# 4626                            4.0                         5.0
# 11262                           3.0                         5.0
# 3731                            2.0                         1.0
# 439                             6.0                         2.0
# 1827                            1.0                         2.0
#
#        away_total_saved_shots_cat  home_discipline_score_avg  \
# 9123                          4.0                 -28.000000
# 809                           2.0                 -26.928571
# 780                           2.0                 -22.328984
# 265                           0.0                 -21.374037
# 12190                         1.0                 -20.875000
# ...                           ...                        ...
# 4626                          4.0                 -15.459459
# 11262                         2.0                 -24.653283
# 3731                          1.0                 -16.821429
# 439                           2.0                 -20.799917
# 1827                          5.0                 -18.923077
#
#        away_discipline_score_avg  gameresult  split
# 9123                  -26.000000           2    0.0
# 809                   -27.785714           1    0.0
# 780                   -24.104167           0    0.0
# 265                   -20.793103           2    0.0
# 12190                 -20.111111           1    0.0
# ...                          ...         ...    ...
# 4626                  -17.810811           0    0.0
# 11262                 -22.076923           0    0.0
# 3731                  -19.357143           0    0.0
# 439                   -23.943396           2    0.0
# 1827                  -19.230769           0    0.0
#
# [2536 rows x 23 columns]

# %%
dev.to_csv('../csvs/Football_Database_dev.csv')

# saving df after finishing feature engineering
with open("../pickles/dev.pkl", "wb") as f:
    pickle.dump(dev, f)  # Save the DataFrame with standard pickle

# %%
dev
# Out:
#        season  home_xGoals  home_ppda  home_total_xAssists  \
# 10682    2019     0.537278     8.2727             0.422670
# 10794    2019     1.027300    18.6000             0.940323
# 2455     2016     1.082450     9.6667             0.972738
# 6463     2017     0.106979    10.0000             0.082412
# 168      2015     0.973378     5.4706             0.720419
# ...       ...          ...        ...                  ...
# 3475     2016     1.256860     4.4286             1.062406
# 1487     2015     0.138495     6.5957             0.125602
# 4070     2014     1.424000     4.9200             1.139164
# 4404     2014     2.011290    11.8261             1.141297
# 9411     2019     2.028830    12.7143             1.862982
#
#        home_total_xGoalsChain  away_xGoals  away_deep  away_ppda  \
# 10682                1.474588     5.346760   4.824998     7.3200
# 10794                3.602186     0.716385  11.000000    14.1875
# 2455                 4.311075     0.505706   3.000000     6.1923
# 6463                 0.519041     1.471830   3.000000     6.6190
# 168                  2.698206     0.401988   4.000000    12.1515
# ...                       ...          ...        ...        ...
# 3475                 4.798060     0.234038   0.000000    11.2609
# 1487                 0.304673     1.003940   4.824998     2.5455
# 4070                 7.039235     1.329110   5.000000    12.0000
# 4404                 5.769247     2.038150   4.824998     6.8571
# 9411                 5.840851     0.445922   3.000000    19.0870
#
#        away_total_xAssists  away_total_xGoalsChain  ...  \
# 10682             3.166349                9.721039  ...
# 10794             0.603594                2.690534  ...
# 2455              0.443530                0.459544  ...
# 6463              1.396730                2.238010  ...
# 168               0.246433                0.434275  ...
# ...                    ...                     ...  ...
# 3475              0.234038                1.192164  ...
# 1487              0.817040                5.563515  ...
# 4070              1.329109                3.736182  ...
# 4404              0.766147                2.161253  ...
# 9411              0.372746                0.745493  ...
#
#        home_shotsOnTarget_cat  away_shotsOnTarget_cat  home_corners_cat  \
# 10682                     6.0                     3.0               7.0
# 10794                     7.0                     4.0               7.0
# 2455                      6.0                     5.0               7.0
# 6463                      0.0                     8.0               1.0
# 168                       4.0                     4.0              11.0
# ...                       ...                     ...               ...
# 3475                      6.0                     5.0               7.0
# 1487                      1.0                     4.0               9.0
# 4070                      5.0                     4.0               7.0
# 4404                      6.0                     6.0               0.0
# 9411                      3.0                     1.0               9.0
#
#        home_total_blocked_shots_cat  home_total_saved_shots_cat  \
# 10682                           4.0                         4.0
# 10794                           3.0                         5.0
# 2455                            2.0                         1.0
# 6463                            0.0                         0.0
# 168                             9.0                         2.0
# ...                             ...                         ...
# 3475                            4.0                         3.0
# 1487                            1.0                         1.0
# 4070                            9.0                         2.0
# 4404                            0.0                         1.0
# 9411                            1.0                         8.0
#
#        away_total_saved_shots_cat  home_discipline_score_avg  \
# 10682                         7.0                 -19.663187
# 10794                         2.0                 -18.166667
# 2455                          3.0                 -21.742021
# 6463                          7.0                 -19.282609
# 168                           2.0                 -21.985505
# ...                           ...                        ...
# 3475                          2.0                 -25.600000
# 1487                          2.0                 -21.183211
# 4070                          0.0                 -12.564516
# 4404                          4.0                 -13.433333
# 9411                          1.0                 -17.599975
#
#        away_discipline_score_avg  gameresult  split
# 10682                 -22.828125           0    0.0
# 10794                 -22.363636           1    0.0
# 2455                  -23.285714           2    0.0
# 6463                  -19.195652           0    0.0
# 168                   -24.942857           1    0.0
# ...                          ...         ...    ...
# 3475                  -24.000000           1    0.0
# 1487                  -23.683333           1    0.0
# 4070                  -15.306452           0    0.0
# 4404                  -16.700000           2    0.0
# 9411                  -20.175000           2    0.0
#
# [2536 rows x 23 columns]

# %%
dev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2536 entries, 10682 to 9411
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   season                        2536 non-null   int64
#  1   home_xGoals                   2536 non-null   float64
#  2   home_ppda                     2536 non-null   float64
#  3   home_total_xAssists           2536 non-null   float64
#  4   home_total_xGoalsChain        2536 non-null   float64
#  5   away_xGoals                   2536 non-null   float64
#  6   away_deep                     2536 non-null   float64
#  7   away_ppda                     2536 non-null   float64
#  8   away_total_xAssists           2536 non-null   float64
#  9   away_total_xGoalsChain        2536 non-null   float64
#  10  home_redCards_binary          2536 non-null   bool
#  11  away_redCards_binary          2536 non-null   bool
#  12  home_yellowCards_cat          2536 non-null   float64
#  13  home_shotsOnTarget_cat        2536 non-null   float64
#  14  away_shotsOnTarget_cat        2536 non-null   float64
#  15  home_corners_cat              2536 non-null   float64
#  16  home_total_blocked_shots_cat  2536 non-null   float64
#  17  home_total_saved_shots_cat    2536 non-null   float64
#  18  away_total_saved_shots_cat    2536 non-null   float64
#  19  home_discipline_score_avg     2536 non-null   float64
#  20  away_discipline_score_avg     2536 non-null   float64
#  21  gameresult                    2536 non-null   int64
#  22  split                         2536 non-null   float64
# dtypes: bool(2), float64(19), int64(2)
# memory usage: 440.8 KB
